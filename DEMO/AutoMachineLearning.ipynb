# %%
from GML import AutoML
# Out:
# GML is up to date
#
#
#
# Feel free to contact us at: https://github.com/Muhammad4hmed/Ghalat-Machine-Learning
# Your GML is ready!

# %%
from sklearn.datasets import load_iris
from sklearn.metrics import accuracy_score
import pandas as pd

# %%
X, y = load_iris(return_X_y=True, as_frame=True)

# %%
Data = pd.concat([X,y],axis=1)

# %%
gml_ml = AutoML()

# %% [markdown]
# The arguments are as follows (Same with GMLRegressor):
#
# X: Independent variable(s) <br>
# y: Dependent variable<br>
# metric: metric of evaluation <br>
# folds: Number of validation folds, default: 5<br>

# %%
gml_ml.GMLClassifier(X, y, metric = accuracy_score, folds = 10)
# Out:
# LogisticRegression got score of 0.9466666666666667 in 10 folds
# DecisionTreeClassifier got score of 0.9400000000000001 in 10 folds
# KNeighborsClassifier got score of 0.9333333333333333 in 10 folds
# SGDClassifier got score of 0.7066666666666667 in 10 folds
# RandomForestClassifier got score of 0.9400000000000001 in 10 folds
# AdaBoostClassifier got score of 0.9400000000000001 in 10 folds
# ExtraTreesClassifier got score of 0.9466666666666667 in 10 folds
# XGBClassifier got score of 0.9333333333333333 in 10 folds
# LGBMClassifier got score of 0.9199999999999999 in 10 folds
# CatBoostClassifier got score of 0.9466666666666667 in 10 folds
# GradientBoostingClassifier got score of 0.9266666666666667 in 10 folds
# GaussianNB got score of 0.9466666666666667 in 10 folds
# MLPClassifier got score of 0.96 in 10 folds

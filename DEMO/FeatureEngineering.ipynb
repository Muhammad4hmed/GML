# %%
from GML import FeatureEngineering
# Out:
# Since the GPL-licensed package `unidecode` is not installed, using Python's `unicodedata` package which yields worse results.
# GML is up to date
#
#
#
# Feel free to contact us at: https://github.com/Muhammad4hmed/GML
# Your GML is ready!

# %%
from sklearn.datasets import load_iris
import pandas as pd

# %%
X, y = load_iris(return_X_y=True, as_frame=True)

# %%
Data = pd.concat([X,y],axis=1)

# %% [markdown]
# The arguments are as follows:
#
# data, <br>
# label,<br>
# fill_missing_data=True,<br>
# method_cat='Mode',<br>
# method_num='Mean',<br>
# drop=True,<br>
# cat_cols=None,<br>
# numeric_cols=None,<br>
# thresh_cat=0.1,<br>
# thresh_numeric=0.1,<br>
# encode_data=True,<br>
# method='TargetEncoder',<br>
# thresh=0.1,<br>
# normalize=True,<br>
# method_transform='LogTransform',<br>
# thresh_numeric_transform=0.1,<br>
# remove_outliers=True,<br>
# qu_fence='inner',<br>
# new_features=True,<br>
# task='classification',<br>
# test_data=None,<br>
# verbose=1,<br>
# feateng_steps=2,<br>

# %% [markdown]
# <b><h3>IMPORTANT</h3> <i>For Feature Selection without Feature Creation, pass new_features=True and feateng_steps=0</i></b>

# %%
fe = FeatureEngineering(Data, 'target')
# Out:
# ==============================
# Handling Missing Data
# ==============================
# There is no missing data
# ==============================
#
#
#
# ==============================
# Encoding Data
# ==============================
# Success
# Data Encoded
# ==============================
#
#
#
# ==============================
# Transforming Data
# ==============================
# Data Transformed
# ==============================
#
#
#
# ==============================
# Handling Outliers
# ==============================
# Before outlier removal
# interquartile range: 2.0
# upper_inner_fence: 5.0
# lower_inner_fence: -3.0
# upper_outer_fence: 8.0
# lower_outer_fence: -6.0
# percentage of records out of inner fences: 0.00
# percentage of records out of outer fences: 0.00
# length of input dataframe: 150
# length of new dataframe after outlier removal: 150
# After outlier removal
# ==============================
#
#
#
# ==============================
# Creating New Features with Features Selection
# ==============================
# [GML] The 2 step feature engineering process could generate up to 406 features.
# [GML] With 150 data points this new feature matrix would use about 0.00 gb of space.
# [FEATURE_ENGINEERING] Step 1: transformation of original features
# [FEATURE_ENGINEERING] Generated 24 transformed features from 4 original features - done.
# [FEATURE_ENGINEERING] Step 2: first combination of features
# [FEATURE_ENGINEERING] Generated 366 feature combinations from 378 original feature tuples - done.
# [FEATURE_ENGINEERING] Generated altogether 391 new features in 2 steps
# [FEATURE_ENGINEERING] Removing correlated features, as well as additions at the highest level
# [FEATURE_ENGINEERING] Generated a total of 112 additional features
# [FEATURE_SELECTION] Scaling data...done.
# [FEATURE_SELECTION] Feature selection run 1/5
# [FEATURE_SELECTION] Feature selection run 2/5
# [FEATURE_SELECTION] Feature selection run 3/5
# [FEATURE_SELECTION] Feature selection run 4/5
# [FEATURE_SELECTION] Feature selection run 5/5
# [FEATURE_SELECTION] 13 features after 5 feature selection runs
# [FEATURE_SELECTION] 6 features after correlation filtering
# [FEATURE_SELECTION] 4 features after noise filtering
# [GML] Computing 4 new features.
# [GML]     4/    4 new features ...done.
# [GML] Final dataframe with 8 feature columns (4 new).
# [GML] Training final classification model.
# [GML] Trained model: largest coefficients:
# [ 10.050155   3.221391 -13.271546]
# 3.992337 * sqrt(petallengthcm)/sepalwidthcm
# 0.713160 * exp(petalwidthcm)/petallengthcm
# 0.463536 * petallengthcm**3*petalwidthcm**2
# 0.115731 * log(petallengthcm)/petallengthcm
# [GML] Final score: 0.9667
# ==============================
#
#
#
# ==============================
# Call get_new_data() function to collect new data

# %%
X_new, y, test = fe.get_new_data()

# %%
X_new
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      exp(petalwidthcm)/petallengthcm  sqrt(petallengthcm)/sepalwidthcm  \
# 0                           0.872431                          0.338062
# 1                           0.872431                          0.394405
# 2                           0.939541                          0.356305
# 3                           0.814269                          0.395079
# 4                           0.872431                          0.328671
# ..                               ...                               ...
# 145                         1.918112                          0.760117
# 146                         1.337179                          0.894427
# 147                         1.420972                          0.760117
# 148                         1.847071                          0.683468
# 149                         1.186205                          0.752773
#
#      petallengthcm**3*petalwidthcm**2  log(petallengthcm)/petallengthcm
# 0                             0.10976                          0.240337
# 1                             0.10976                          0.240337
# 2                             0.08788                          0.201819
# 3                             0.13500                          0.270310
# 4                             0.10976                          0.240337
# ..                                ...                               ...
# 145                         743.81632                          0.317050
# 146                         451.25000                          0.321888
# 147                         562.43200                          0.317050
# 148                         832.98456                          0.312296
# 149                         429.78924                          0.319459
#
# [150 rows x 8 columns]
